# %%
# -*- coding: utf-8 -*-
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
font = FontProperties(fname=r"C:\Windows\Fonts\simhei.ttf", size=14)

# %%
beijing = [17,17,23,43]
shanghai = ['19%','4%','23%','54%']
guangzhou = ['53%','25%','13%','9%']
shenzhen = ['41%','22%','20%','17%']

label = ['2-3 years','3-4 years','4-5 years','5+ years']
color = ['red','green','yellow','purple']

# %%
indic = []

#我们将数据最大的突出显示
for value in beijing:
    if value == max(beijing):
        indic.append(0.1)
    else:
        indic.append(0)

# %%
plt.pie(
    beijing,
    labels=label,
    colors=color,
    startangle=90,
    shadow=True,
    explode=tuple(indic),#tuple方法用于将列表转化为元组
    autopct='%1.1f%%'#是数字1，不是l
)


plt.title(u'饼图示例——统计北京程序员工龄', FontProperties=font)

plt.show()

# %%
import pandas as pd

# %%
df=pd.read_csv("data.csv")

# %%
df
# Out:
#    Unnamed: 0  Prices  Amount Action  C
# 0           0       3      57   Sell  1
# 1           1      89      42   Sell  1
# 2           2      45      70    Buy -1
# 3           3       6      43   Sell  1
# 4           4      60      47   Sell  1
# 5           5      19      16    Buy -1
# 6           6      56      89   Sell  1
# 7           7       3      28    Buy -1
# 8           8      56      69   Sell  1
# 9           9      90      49    Buy -1

# %%
from matplotlib import colors

# %%
bingzhuang=df['Prices'].apply(lambda x :x/df['Prices'].sum())

# %%
indic = []

#我们将数据最大的突出显示
for value in bingzhuang:
    if value == max(beijing):
        indic.append(0.1)
    else:
        indic.append(0)

# %%
plt.pie(
    bingzhuang,
    labels=bingzhuang,
    colors=color,
    startangle=90,
    shadow=True,
    explode=tuple(indic),#tuple方法用于将列表转化为元组
    autopct='%1.1f%%'#是数字1，不是l
)


plt.title(u'Prices', FontProperties=font)

plt.show()
