# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
california_housing_dataframe = pd.read_csv(r"..\\dataset\\california_housing_train.csv", sep=",")

# %%
print(california_housing_dataframe.head(5))
print("california_housing_dataframe.shape",california_housing_dataframe.shape)
california_housing_dataframe.describe()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0
# california_housing_dataframe.shape (17000, 9)
#           longitude      latitude  housing_median_age   total_rooms  \
# ...

# %%
print(california_housing_dataframe.housing_median_age)
# Out:
# 0        15.0
# 1        19.0
# 2        17.0
# 3        14.0
# 4        20.0
# 5        29.0
# 6        25.0
# 7        41.0
# 8        34.0
# 9        46.0
# 10       16.0
# 11       21.0
# 12       48.0
# 13       31.0
# 14       15.0
# 15       17.0
# 16       28.0
# 17       21.0
# 18       17.0
# 19       17.0
# 20       20.0
# 21       24.0
# 22       20.0
# 23       15.0
# 24       18.0
# 25       34.0
# 26       30.0
# 27       14.0
# 28       32.0
# 29       23.0
#          ...
# 16970    52.0
# 16971    52.0
# 16972    43.0
# 16973    39.0
# 16974    30.0
# 16975    26.0
# 16976    13.0
# 16977    32.0
# 16978    39.0
# 16979    37.0
# 16980    34.0
# 16981    33.0
# 16982    35.0
# 16983    15.0
# 16984    37.0
# 16985    30.0
# 16986    21.0
# 16987    17.0
# 16988    20.0
# 16989    32.0
# 16990    28.0
# 16991    11.0
# 16992    52.0
# 16993    52.0
# 16994    32.0
# 16995    52.0
# 16996    36.0
# 16997    17.0
# 16998    19.0
# 16999    52.0
# ...

# %%
california_housing_dataframe.hist('housing_median_age')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000000168885F8>]],
#       dtype=object)

# %%
from pandas import Series,DataFrame
from numpy.random import randn
import numpy as np
import matplotlib.pyplot as plt
df = DataFrame(abs(randn(10,5)),columns=['A','B','C','D','E'],index = np.arange(0,100,10))
df.plot(kind='bar')
plt.show()

# %%
df = pd.DataFrame({ 'a_wood' : np.random.randn(100),
                 'a_grassland' : np.random.randn(100),
                 'a_settlement' : np.random.randn(100),
                 'b_wood' : np.random.randn(100),
                 'b_grassland' : np.random.randn(100),
                  'b_settlement' : np.random.randn(100)})

# %%
df.head(10)
# Out:
#    a_grassland  a_settlement    a_wood  b_grassland  b_settlement    b_wood
# 0    -1.408899     -1.081660 -1.401086    -0.089161      1.163786 -0.213905
# 1     0.255008     -0.764054  0.455270     0.213235     -1.705758 -0.891639
# 2    -0.354088      0.811859 -0.303425     0.542359      0.586513  0.333768
# 3     1.012525      1.311637 -1.029392    -1.168025     -0.697907 -2.686167
# 4    -0.388868     -0.622569 -0.016709     2.030629      1.317983 -0.442276
# 5     0.129056      1.069155 -1.571098    -0.575549     -1.364662  0.695561
# 6    -0.711006     -0.354161  0.504071     2.056202      0.337956  0.536199
# 7     0.365984     -1.617413 -0.361999    -0.328750      0.815381 -0.132284
# 8     1.121013      0.679012 -0.414732     0.974975     -1.340409 -0.411819
# 9     0.039769     -1.802065  1.084183    -0.430311      0.872677  0.693647

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')
m=0
for i in range(2):
    for j in range(3):
        df.hist(column = df.columns[m], bins = 12, ax=ax[i,j], figsize=(20, 18))
        m+=1
